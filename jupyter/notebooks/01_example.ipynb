# %%
print("Hello World!")

# %%
# You can define a variable like this
i = 2026
print(f"Current value of i={i}")

# %%
# You can access the variable from another cell
print(f"i={i}")
# And modify it
i = -3
print(f"New value of i={i}")
